# %% [markdown]
# <h1 align="center">Classificação de Pontuação de Crédito com Machine Learning</h1>

# %% [markdown]
# Data Scientist Jr.: Karina Gonçalves Soares

# %% [markdown]
# Link de estudo:
# * [Credit Score Classification with Machine Learning]("https://thecleverprogrammer.com/2022/12/05/credit-score-classification-with-machine-learning/")

# %% [markdown]
# Nesse script iremos análisar a classificação de pontuação de crédito usando aprendizado de máquina supervisionado com o algoritmo de classificação Random Forest Classifier.
#
# Nós iremos análisar a sovábilidade do cliente usando o rótulo padrão utilizado pelos bancos e empresas de cartão de crédito:
# 1.Bom
# 2.Padrão
# 3.Ruim
#
# Um cliente com  boa pontuação de crédito irá receber empréstimo de qualquer banco ou empresa.
#
# O dados utilizados nesse estudo estão disponíveis no link a seguir:
# [Dataset]('https://statso.io/credit-score-classification-case-study/')

# %% [markdown]
# ### <font color='Pink'>1.</font>Importando bibliotecas e conjunto de dados:

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = "plotly_white"

# %%
data = pd.read_csv("/home/karinag/karina_python/git-hub/Machine_Learning/2.20_ML_projects/dataset/train_credit_score_data.csv")

# %%
data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...
